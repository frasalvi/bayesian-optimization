# %%
if 1:
  # !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading bayesian-optimization-1.2.0.tar.gz (14 kB)
# Requirement already satisfied: numpy>=1.9.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from bayesian-optimization) (1.20.3)
# Requirement already satisfied: scipy>=0.14.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from bayesian-optimization) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from bayesian-optimization) (0.24.2)
# Requirement already satisfied: joblib>=0.11 in /home/martin/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/martin/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.18.0->bayesian-optimization) (2.2.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-py3-none-any.whl size=11685 sha256=3f7311c23f32e85c7e64c5e4ccf0eb4ed8148dcd2efef9d85d379094f495ba94
#   Stored in directory: /home/martin/.cache/pip/wheels/14/98/74/190efced439ab92ca551550906290338ba5b64cfc9d0927765
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %% [markdown]
# # Demo for Rosenbrock function
# In this notebook you will see the pipeline for generating the results seen in the report considering the Rosenbrock function.

# %%
import numpy as np
import scipy.stats as st
import random
import matplotlib.pyplot as plt
from matplotlib import ticker
from bayes_opt import BayesianOptimization

from helpers import *

# %% [markdown]
# ## Rosenbrock function
# * Minimum is about 1e-6

# %%
x = np.linspace(-2, 2, 1000)
y = np.linspace(-1, 3, 1000)
xx, yy = np.meshgrid(x, y)

rosenbrock = Rosenbrock(1, 100)
zz = rosenbrock(xx, yy)

plt.figure(1, (8, 5))
plt.contour(xx, yy, zz, levels=np.logspace(-4, 3, 10), alpha=0.4, extend='both', locator=ticker.LogLocator(), colors='white')
plt.contourf(xx, yy, zz, levels=np.logspace(-4, 3, 30), alpha=0.9, extend='both', locator=ticker.LogLocator())
plt.colorbar(ticks=np.logspace(-6, 3, 10))
plt.axis('scaled')
plt.axis("off")

plt.xlabel('x')
plt.ylabel('y')
plt.savefig("figures/rosenbrock.png")
plt.show()

# %%
np.min(zz)
# Out:
# 1.002103405007144e-06

# %% [markdown]
# ##Gradient descent on Rosenbrock with random initialization

# %%
lr = 1e-5
max_num_iterations = 1000
num_trials = 1000

losses_1000 = np.zeros((max_num_iterations,num_trials))

for i in range(num_trials):
    x = random.uniform(-2, 2)
    y = random.uniform(-1, 3)
    objectives, xs = gradient_descent(rosenbrock, x, y, lr, max_num_iterations, print_p=False)
    losses_1000[:,i] = objectives

x = np.arange(1,max_num_iterations+1)
mean_losses_1000 = np.mean(losses_1000, axis=1)
plt.plot(x, mean_losses_1000)
plt.xlabel("Number of iterations")
plt.ylabel("Rosenbrock value")
plt.title("Gradient descent with random initialization, lr=1e-5")
# Out:
# Text(0.5, 1.0, 'Gradient descent with random initialization, lr=1e-5')

# %%
lr = 1e-4
max_num_iterations = 100
num_trials = 1000

losses_100 = np.zeros((max_num_iterations,num_trials))

for i in range(num_trials):
    x = random.uniform(-2, 2)
    y = random.uniform(-1, 3)
    objectives, xs = gradient_descent(rosenbrock, x, y, lr, max_num_iterations, print_p=False)
    losses_100[:,i] = objectives

x = np.arange(1,max_num_iterations+1)
mean_losses_100 = np.mean(losses_100, axis=1)
plt.plot(x, mean_losses_100)
plt.xlabel("Number of iterations")
plt.ylabel("Rosenbrock value")
plt.title("Gradient descent with random initialization, lr=1e-4")
# Out:
# Text(0.5, 1.0, 'Gradient descent with random initialization, lr=1e-4')

# %% [markdown]
# ##Gradient descent on Rosenbrock with bayesian opt initialization
#
# * Running the following cells can take about 10 minutes in total. Decrease number of trials for fast run.

# %%
rosenbrock = Rosenbrock(1, 100)

def negative_rosenbrock(x, y):
  return -1*rosenbrock(x,y)

pbounds = {"x": [-2, 2], "y": [-1, 3]}

# %% [markdown]
# #### Acquisition function: Upper confidence bound (UCB), lower learning rate

# %%
lr = 1e-5
max_num_iterations = 1000
num_trials = 1000
kappa = 0.1

# %%
bayes_opt_UCB_losses_LOW = np.zeros((max_num_iterations,num_trials))

for i in range(num_trials):and plots you use in the paper.
– Documentation: Your system must be clearly described in your PDF report and also well-documented
in the code itself. A useful ReadMe file must be provided.
    if i % 100 == 0:
      print("Trial num: {}".format(i))
    optimizer = BayesianOptimization(f = negative_rosenbrock,
                                    pbounds = pbounds, 
                                    verbose = 0)
    optimizer.maximize(init_points = 5, n_iter = 5, acq="ucb", kappa=kappa)
    best = optimizer.max["params"]
    x = best["x"]
    y = best["y"]

    objectives, xs = gradient_descent(rosenbrock, x, y, lr, max_num_iterations, print_p=False)
    bayes_opt_UCB_losses_LOW[:,i] = objectives
# Out:
# Trial num: 0
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     178             try:
# --> 179                 x_probe = next(self._queue)
#     180             except StopIteration:
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in __next__(self)
#      24         if self.empty:
# ---> 25             raise StopIteration("Queue is empty, no more objects to retrieve.")
#      26         obj = self._queue[0]
#
# StopIteration: Queue is empty, no more objects to retrieve.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18172/1222745260.py in <module>
#       7                                     pbounds = pbounds,
#       8                                     verbose = 0)
# ----> 9     optimizer.maximize(init_points = 5, n_iter = 5, acq="ucb", kappa=kappa)
#      10     best = optimizer.max["params"]
#      11     x = best["x"]
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in maximize(self, init_points, n_iter, acq, kappa, kappa_decay, kappa_decay_delay, xi, **gp_params)
#     180             except StopIteration:
#     181                 util.update_params()
# --> 182                 x_probe = self.suggest(util)
#     183                 iteration += 1
#     184
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/bayesian_optimization.py in suggest(self, utility_function)
#     129
#     130         # Finding argmax of the acquisition function.
# --> 131         suggestion = acq_max(
#     132             ac=utility_function.utility,
#     133             gp=self._gp,
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/util.py in acq_max(ac, gp, y_max, bounds, random_state, n_warmup, n_iter)
#      53     for x_try in x_seeds:
#      54         # Find the minimum of minus the acquisition function
# ---> 55         res = minimize(lambda x: -ac(x.reshape(1, -1), gp=gp, y_max=y_max),
#      56                        x_try.reshape(1, -1),
#      57                        bounds=bounds,
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     621                                   **options)
#     622     elif meth == 'l-bfgs-b':
# --> 623         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                                 callback=callback, **options)
#     625     elif meth == 'tnc':
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/util.py in <lambda>(x)
#      53     for x_try in x_seeds:
#      54         # Find the minimum of minus the acquisition function
# ---> 55         res = minimize(lambda x: -ac(x.reshape(1, -1), gp=gp, y_max=y_max),
#      56                        x_try.reshape(1, -1),
#      57                        bounds=bounds,
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/util.py in utility(self, x, gp, y_max)
#     103     def utility(self, x, gp, y_max):
#     104         if self.kind == 'ucb':
# --> 105             return self._ucb(x, gp, self.kappa)
#     106         if self.kind == 'ei':
#     107             return self._ei(x, gp, y_max, self.xi)
#
# ~/anaconda3/lib/python3.9/site-packages/bayes_opt/util.py in _ucb(x, gp, kappa)
#     113         with warnings.catch_warnings():
#     114             warnings.simplefilter("ignore")
# --> 115             mean, std = gp.predict(x, return_std=True)
#     116
#     117         return mean + kappa * std
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/gaussian_process/_gpr.py in predict(self, X, return_std, return_cov)
#     322
#     323         if self.kernel is None or self.kernel.requires_vector_input:
# --> 324             X = check_array(X, ensure_2d=True, dtype="numeric")
#     325         else:
#     326             X = check_array(X, ensure_2d=False, dtype=None)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     658         # thereby passing the test made in the lines following the scope
#     659         # of warnings context manager.
# --> 660         with warnings.catch_warnings():
#     661             try:
#     662                 warnings.simplefilter('error', ComplexWarning)
#
# ~/anaconda3/lib/python3.9/warnings.py in __init__(self, record, module)
#     444         """
#     445         self._record = record
# --> 446         self._module = sys.modules['warnings'] if module is None else module
#     447         self._entered = False
#     448
#
# KeyboardInterrupt:

# %%
plot_w_CI(bayes_opt_UCB_losses_LOW, losses_1000, max_num_iterations, 
          "Random versus UCB GP bay. opt. for initialization, lr=1e-5", 
          "Gradient descent iteration", 
          "Rosenbrock value", 
          "figures/rosenbrock_GP_95_CI_1000.pdf")

# %% [markdown]
# #### Acquisition function: Upper confidence bound (UCB), higher learning rate

# %%
lr = 1e-4
max_num_iterations = 100
num_trials = 1000
kappa = 0.1

# %%
bayes_opt_UCB_losses_HIGH = np.zeros((max_num_iterations,num_trials))

for i in range(num_trials):
    if i % 100 == 0:
      print("Trial num: {}".format(i))
    optimizer = BayesianOptimization(f = negative_rosenbrock,
                                    pbounds = pbounds, 
                                    verbose = 0)
    optimizer.maximize(init_points = 5, n_iter = 5, acq="ucb", kappa=kappa)
    best = optimizer.max["params"]
    x = best["x"]
    y = best["y"]

    objectives, xs = gradient_descent(rosenbrock, x, y, lr, max_num_iterations, print_p=False)
    bayes_opt_UCB_losses_HIGH[:,i] = objectives

# %%
plot_w_CI(bayes_opt_UCB_losses_HIGH, losses_100, max_num_iterations, 
          "Random versus UCB GP bay. opt. for initialization, lr=1e-4", 
          "Gradient descent iteration", 
          "Rosenbrock value", 
          "figures/rosenbrock_GP_95_CI_100.pdf")

# %% [markdown]
# #### Finally a subplot with the results combined

# %%
plot_w_CI_subplot([bayes_opt_UCB_losses_LOW,bayes_opt_UCB_losses_HIGH], [losses_1000, losses_100], [1000,100], 
          "Random versus UCB GP bay. opt. for initialization", 
          ["learning rate = 1e-5", "learning rate = 1e-4"],
          ["Gradient descent iteration","Gradient descent iteration"], 
          ["Rosenbrock value","Rosenbrock value"], 
          "figures/rosenbrock_GP_95_CI_SUBPLOT.pdf")
